# %%
import os
import sys
import pandas as pd

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from scripts.data_preprocessing import *

# %% [markdown]
# ## Sentiments Cleaning

# %%
sentiment_train = pd.read_csv("../data/raw/train_data.csv")
sentiment_test = pd.read_csv("../data/raw/test_data.csv")

# %%
cleaned_sentiment_train = preprocess_sentiment(sentiment_train)
cleaned_sentiment_test = preprocess_sentiment(sentiment_test)

# %%
cleaned_sentiment_test.head()
# Out:
# 0    i loooooooovvvvvveee my kindle not that the dx...
# 1    reading my kindle love it lee childs is good read
# 2    ok first assesment of the kindle it fucking rocks
# 3    you ll love your kindle i ve had mine for a fe...
# 4    fair enough but i have the kindle and i think ...
# Name: sentence, dtype: object

# %% [markdown]
# ## G0emotions Cleaning

# %%
goemotions1 = pd.read_csv("../data/raw/goemotions_1.csv")
goemotions2 = pd.read_csv("../data/raw/goemotions_2.csv")
goemotions3 = pd.read_csv("../data/raw/goemotions_3.csv")

# %%
cleaned_goemotions1 = preprocess_goemotions(goemotions1)
cleaned_goemotions2 = preprocess_goemotions(goemotions2)
cleaned_goemotions3 = preprocess_goemotions(goemotions3)

# %% [markdown]
# ## Artifacts

# %%
cleaned_sentiment_train.to_csv("../data/processed/sentiment_train.csv", index=False)
cleaned_sentiment_test.to_csv("../data/processed/sentiment_test.csv", index=False)
cleaned_goemotions1.to_csv("../data/processed/cleaned_goemotions1.csv", index=False)
cleaned_goemotions2.to_csv("../data/processed/cleaned_goemotions2.csv", index=False)
cleaned_goemotions3.to_csv("../data/processed/cleaned_goemotions3.csv", index=False)
